# %% [markdown]
# # Table 6. Reasons for video abandonment

# %%
from util import *

df = getPreProcessingDF('../preProcess.xlsx')
df = df[df['Likert'] >= 1]
res = df.groupby('AbandonmentReason')['Likert'].agg(['mean', 'median', 'std', 'count'])
res.sort_values(by='mean', ascending=False)
# Out:
#                                     mean  median       std  count
# AbandonmentReason
# Video Ended                     6.370079     7.0  0.861921    127
# Desire Satisfired               5.879747     6.0  1.065223    316
# Wanted to Watch Something Else  5.388889     5.5  1.224235     90
# Others                          5.007812     5.0  1.466133    128
# Already Knew the Content        4.837838     5.0  1.500250     37
# Undesired Content               4.082192     4.0  1.816234     73
# Decreased Interest              4.078431     4.0  1.355058    204
# Goal Not Achieved               3.650602     4.0  1.193823     83
